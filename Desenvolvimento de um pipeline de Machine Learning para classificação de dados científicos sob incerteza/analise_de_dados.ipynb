# %%
import pandas as pd

df_features = pd.read_csv(r'C:\Users\User\gpr\simulação\sim1\Features.csv')
df_labels = pd.read_csv(r'C:\Users\User\gpr\simulação\sim1\labels.csv')

df_features = df_features.merge(df_labels,right_index=True,left_index=True)
display(df_features)

df_features.to_csv('Dados completos.csv', index=False)

df_features.to_csv(
    'Dados completos.csv',
    sep=';',
    index=False,
    encoding='utf-8-sig'
)

df_com_cilindro = df_features[df_features['Label'] == 1]
df_sem_cilindro = df_features[df_features['Label'] == 0]
display(df_com_cilindro.describe())
display(df_sem_cilindro.describe())
# Out:
#         Média    Variância      Máximo       Energia  Skewness   Kurtosis  \
# 0   -8.118985  5046.064678  426.044495  1.953800e+08 -1.530590   8.882906
# 1   -7.001265  2914.390897  319.997040  1.132615e+08 -0.170471   5.186916
# 2   -8.304564  4730.422292  412.039764  1.834326e+08  0.062562   6.203662
# 3   -6.039109  3363.004739  359.805054  1.299280e+08  0.507617   7.962693
# 4   -4.586327  2934.315264  322.917328  1.129535e+08  0.762987   6.374970
# ..        ...          ...         ...           ...       ...        ...
# 995 -8.251102  2303.713750  518.999451  9.064998e+07 -3.670779  23.739924
# 996 -9.545670  1490.886697  257.687439  6.046429e+07 -2.448785   8.366446
# 997 -7.151956  5610.206699  384.289520  2.163771e+08  0.213659   6.120610
# 998 -8.500808  2158.034073  248.050430  8.524198e+07 -1.234216   5.871989
# 999 -8.509017  1807.065572  302.602753  7.183330e+07 -2.078960   9.192381
#
#      Label
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
# ...
